// %% [markdown]
// # Lab 16 Exercise 2

// %% [markdown]
// ## Abstract class

// %% [markdown]
// ![alt text](./Pictures/image02.png)

// %% [markdown]
// 1.สร้าง console application project
//
// ```cmd
// dotnet new console --name Lab16_Ex02
// ```

// %% [markdown]
// 2.เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// ```csharp
// Shape[] shapes = new Shape[3];
// shapes[0] = new Rectangle();
// shapes[1] = new Triangle();
// shapes[2] = new Circle();
//
// foreach (var shape in shapes)
// {
//     shape.Draw();
// }
//
// abstract class Shape
// {
//     public abstract void Draw();
// }
// class Rectangle: Shape
// {
//     public override void Draw()
//     {
//         System.Console.WriteLine("Draw a rectangle");
//     }
// }
// class Triangle: Shape
// {
//     public override void Draw()
//     {
//         System.Console.WriteLine("Draw a triangle");
//     }
// }
// class Circle: Shape
// {
//     public override void Draw()
//     {
//         System.Console.WriteLine("Draw a circle");
//     }
// }
// ```

// %% [markdown]
// 3.Build project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet build  Lab16_Ex02
// ```
//
// ถ้ามีที่ผิดพลาดในโปรแกรม ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// 4.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 5.Run project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet run --project Lab16_Ex02
// ```

// %% [markdown]
// 6.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 7.อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// การใช้ polymorphism ในกรณีนี้ทำให้สามารถเรียกเมธอด Draw() ที่ถูก implement ในแต่ละคลาสย่อย (Rectangle, Triangle, Circle) โดยไม่จำเป็นต้องระบุชนิดของอ็อบเจกต์ในลูป foreach
